# %%
# Importing the library
from LDA_Topic_Generation import LDA_Modeling

# %%
# Load the modeling instance with the file path and cleaned text column name
lda = LDA_Modeling('sample.xlsx', 'Description_notes')

# %%
# Execute the LDA model for the text column entered
# Choose the model options or iterate the preprocessing
# Finally get the topic labelled data, top N keywords and the optimal model chosen.
df, kw, model = lda.modeling()
# Out:
# Num Topics = 3  has Coherence Value of 0.3701
# Num Topics = 4  has Coherence Value of 0.3776
# Num Topics = 5  has Coherence Value of 0.4477
# Num Topics = 6  has Coherence Value of 0.4503
# Num Topics = 7  has Coherence Value of 0.4373
# Num Topics = 8  has Coherence Value of 0.4351
# Num Topics = 9  has Coherence Value of 0.5503
# Num Topics = 10  has Coherence Value of 0.4862
# Num Topics = 11  has Coherence Value of 0.5549
# Num Topics = 12  has Coherence Value of 0.5275
# Num Topics = 13  has Coherence Value of 0.5582
# Num Topics = 14  has Coherence Value of 0.5312
# Num Topics = 15  has Coherence Value of 0.5378
# Num Topics = 16  has Coherence Value of 0.5634
# Num Topics = 17  has Coherence Value of 0.5782
# Num Topics = 18  has Coherence Value of 0.5671
# Num Topics = 19  has Coherence Value of 0.5723
# Enter value of t (topics) for keywords: 17
# Enter number of words you want to analyse/topic: 20
#     Topic                                           Keywords
# ...

# %%
df
# Out:
#     Dominant_Topic  Topic_Perc_Contrib  \
# 0              2.0              0.3306
# 1              9.0              0.2373
# 2              7.0              0.1263
# 3              3.0              0.1581
# 4              9.0              0.1666
# 5              2.0              0.1211
# 6              2.0              0.1247
# 7              2.0              0.1211
# 8              7.0              0.1705
# 9             10.0              0.3018
# 10             7.0              0.3026
# 11             4.0              0.1037
# 12             6.0              0.1007
# 13             2.0              0.1286
# 14            15.0              0.2904
# 15            16.0              0.1183
# 16            14.0              0.1584
# 17             6.0              0.1577
# 18             3.0              0.3042
# 19             5.0              0.1575
# 20             0.0              0.1103
# 21             3.0              0.1101
# 22             3.0              0.1440
# ...

# %%
kw
# Out:
#     Topic                                           Keywords
# 0       0  ['ccp', 'interface', 'number', 'ne', 'correctl...
# 1       1  ['follow', 'equipment', 'run', 'problem', 'typ...
# 2       2  ['job', 'vsap', 'engineer', 'cancel', 'dollar'...
# 3       3  ['dispatch', 'queue', 'coa', 'install', 'gener...
# 4       4  ['location', 'clli', 'correct', 'default', 'sh...
# 5       5  ['change', 'cllinet', 'frc', 'code', 'vsap', '...
# 6       6  ['material', 'ccc', 'card', 'place', 'bundle',...
# 7       7  ['item', 'line', 'assembly', 'shelf', 'bay', '...
# 8       8  ['budget', 'area', 'move', 'approver', 'wendy'...
# 9       9  ['error', 'report', 'process', 'creation', 've...
# 10     10  ['request', 'vbuild', 'submit', 'click', 'ewo'...
# 11     11  ['project', 'remove', 'invalid', 'approve', 'a...
# 12     12  ['teo', 'create', 'material', 'reply', 'band',...
# 13     13  ['system', 'complete', 'icon', 'receive', 'mes...
# ...

# %%
model
